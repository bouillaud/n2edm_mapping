# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
G10s = np.load("../data/G10s_runstart1095_runstop1150_lmax1.npy")

# %%
G10s
# Out:
# array([-0.170325  , -0.40833918, -0.33965359, -0.25052165, -0.30423883,
#        -0.33526538, -0.3551547 , -0.2751263 , -0.41029529, -0.39744849,
#        -0.21941057, -0.43265126, -0.51581004, -0.38835465, -0.55203212,
#        -0.38011248, -0.43041856, -0.37597182, -0.43907144, -0.7095712 ,
#        -0.3594479 , -0.48362431, -0.49265886, -0.53969505, -0.60196133,
#        -0.49226067, -0.4619047 , -0.50698009, -0.54193968, -0.38801662,
#        -0.95084532, -0.54625968, -0.32543496, -0.53712998, -0.53469077,
#        -0.53518408, -0.44406138, -0.47638353, -0.50638937, -0.57530649,
#        -0.42219518, -0.36183885, -0.44696711, -0.33856549, -0.40551462,
#        -0.41394398, -0.33983697, -0.32910365, -0.38945118, -0.21616494,
#        -0.30472909, -0.13683225, -0.31443864, -0.25810943, -0.26810405])

# %%
runs = range(1095, 1150)

plt.plot(runs, G10s, "-o")
plt.grid()

plt.ylim(-1, 0)
plt.yticks(np.arange(-1, 0.1, 0.1))
plt.xlim(1095, 1150)

plt.xlabel("Run number")
plt.ylabel(r"$G_{10}$ [pT/cm]")
# Out:
# Text(0, 0.5, '$G_{10}$ [pT/cm]')
